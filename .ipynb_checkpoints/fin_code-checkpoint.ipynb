# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1) Pre-Processing

# %%
user_data=pd.read_csv('application_record.csv')
record=pd.read_csv('credit_record.csv')

# %%
user_data.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0        Civil marriage   Rented apartment      -12005          -4542
# 1        Civil marriage   Rented apartment      -12005          -4542
# 2               Married  House / apartment      -21474          -1134
# 3  Single / not married  House / apartment      -19110          -3051
# 4  Single / not married  House / apartment      -19110          -3051
#
#    FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 0           1                1           0           0             NaN
# 1           1                1           0           0             NaN
# 2           1                0           0           0  Security staff
# 3           1                0           1           1     Sales staff
# 4           1                0           1           1     Sales staff
#
#    CNT_FAM_MEMBERS
# 0              2.0
# 1              2.0
# 2              2.0
# 3              1.0
# 4              1.0

# %%
record.head()
# Out:
#         ID  MONTHS_BALANCE STATUS
# 0  5001711               0      X
# 1  5001711              -1      0
# 2  5001711              -2      0
# 3  5001711              -3      0
# 4  5001712               0      C

# %% [markdown]
# ## 1.1) Setting up target values to binary type

# %%
record['STATUS'].unique()
# Out:
# array(['X', '0', 'C', '1', '2', '3', '4', '5'], dtype=object)

# %%
record=record.replace({"STATUS":{'X':-1,'C':-1}})

# %%
record.head()
# Out:
#         ID  MONTHS_BALANCE STATUS
# 0  5001711               0     -1
# 1  5001711              -1      0
# 2  5001711              -2      0
# 3  5001711              -3      0
# 4  5001712               0     -1

# %%
record.dtypes
# Out:
# ID                 int64
# MONTHS_BALANCE     int64
# STATUS            object
# dtype: object

# %%
record['STATUS']=record['STATUS'].astype('int64')
record.dtypes
# Out:
# ID                int64
# MONTHS_BALANCE    int64
# STATUS            int64
# dtype: object

# %%
record['STATUS']=record['STATUS']+1
record=record.drop(['MONTHS_BALANCE'],axis=1)

# %%
record.head()
# Out:
#         ID  STATUS
# 0  5001711       0
# 1  5001711       1
# 2  5001711       1
# 3  5001711       1
# 4  5001712       0

# %%
# record=record.groupby('ID')['STATUS'].apply(pd.Series.mode)
# record.to_frame()
# record=record.reset_index()
# record=record.drop(['level_1'],axis=1)
# record=record.groupby('ID').max('STATUS') 
# record.head()

# %%
record=record.groupby('ID').max('STATUS')

# %% [markdown]
# ## 1.2) Merging Record data with the Personal Data

# %%
record=pd.merge(user_data,record,how='inner',on='ID')
record
# Out:
#             ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0      5008804           M            Y               Y             0
# 1      5008805           M            Y               Y             0
# 2      5008806           M            Y               Y             0
# 3      5008808           F            N               Y             0
# 4      5008809           F            N               Y             0
# ...        ...         ...          ...             ...           ...
# 36452  5149828           M            Y               Y             0
# 36453  5149834           F            N               Y             0
# 36454  5149838           F            N               Y             0
# 36455  5150049           F            N               Y             0
# 36456  5150337           M            N               Y             0
#
#        AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0              427500.0               Working               Higher education
# 1              427500.0               Working               Higher education
# 2              112500.0               Working  Secondary / secondary special
# 3              270000.0  Commercial associate  Secondary / secondary special
# 4              270000.0  Commercial associate  Secondary / secondary special
# ...                 ...                   ...                            ...
# 36452          315000.0               Working  Secondary / secondary special
# 36453          157500.0  Commercial associate               Higher education
# 36454          157500.0             Pensioner               Higher education
# 36455          283500.0               Working  Secondary / secondary special
# 36456          112500.0               Working  Secondary / secondary special
#
#          NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0            Civil marriage   Rented apartment      -12005          -4542
# 1            Civil marriage   Rented apartment      -12005          -4542
# 2                   Married  House / apartment      -21474          -1134
# 3      Single / not married  House / apartment      -19110          -3051
# 4      Single / not married  House / apartment      -19110          -3051
# ...                     ...                ...         ...            ...
# 36452               Married  House / apartment      -17348          -2420
# 36453               Married  House / apartment      -12387          -1325
# 36454               Married  House / apartment      -12387          -1325
# 36455               Married  House / apartment      -17958           -655
# 36456  Single / not married   Rented apartment       -9188          -1193
#
#        FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 0               1                1           0           0             NaN
# 1               1                1           0           0             NaN
# 2               1                0           0           0  Security staff
# 3               1                0           1           1     Sales staff
# 4               1                0           1           1     Sales staff
# ...           ...              ...         ...         ...             ...
# 36452           1                0           0           0        Managers
# 36453           1                0           1           1  Medicine staff
# 36454           1                0           1           1  Medicine staff
# 36455           1                0           0           0     Sales staff
# 36456           1                0           0           0        Laborers
#
#        CNT_FAM_MEMBERS  STATUS
# 0                  2.0       2
# 1                  2.0       2
# 2                  2.0       1
# 3                  1.0       1
# 4                  1.0       0
# ...                ...     ...
# 36452              2.0       6
# 36453              2.0       6
# 36454              2.0       6
# 36455              2.0       3
# 36456              1.0       3
#
# [36457 rows x 19 columns]

# %%
# record['DAYS_BIRTH']=record['DAYS_BIRTH']/-365.25
# record['DAYS_EMPLOYED']=record['DAYS_EMPLOYED']/-365.25

# %%
record
# Out:
#             ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0      5008804           M            Y               Y             0
# 1      5008805           M            Y               Y             0
# 2      5008806           M            Y               Y             0
# 3      5008808           F            N               Y             0
# 4      5008809           F            N               Y             0
# ...        ...         ...          ...             ...           ...
# 36452  5149828           M            Y               Y             0
# 36453  5149834           F            N               Y             0
# 36454  5149838           F            N               Y             0
# 36455  5150049           F            N               Y             0
# 36456  5150337           M            N               Y             0
#
#        AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0              427500.0               Working               Higher education
# 1              427500.0               Working               Higher education
# 2              112500.0               Working  Secondary / secondary special
# 3              270000.0  Commercial associate  Secondary / secondary special
# 4              270000.0  Commercial associate  Secondary / secondary special
# ...                 ...                   ...                            ...
# 36452          315000.0               Working  Secondary / secondary special
# 36453          157500.0  Commercial associate               Higher education
# 36454          157500.0             Pensioner               Higher education
# 36455          283500.0               Working  Secondary / secondary special
# 36456          112500.0               Working  Secondary / secondary special
#
#          NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0            Civil marriage   Rented apartment      -12005          -4542
# 1            Civil marriage   Rented apartment      -12005          -4542
# 2                   Married  House / apartment      -21474          -1134
# 3      Single / not married  House / apartment      -19110          -3051
# 4      Single / not married  House / apartment      -19110          -3051
# ...                     ...                ...         ...            ...
# 36452               Married  House / apartment      -17348          -2420
# 36453               Married  House / apartment      -12387          -1325
# 36454               Married  House / apartment      -12387          -1325
# 36455               Married  House / apartment      -17958           -655
# 36456  Single / not married   Rented apartment       -9188          -1193
#
#        FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 0               1                1           0           0             NaN
# 1               1                1           0           0             NaN
# 2               1                0           0           0  Security staff
# 3               1                0           1           1     Sales staff
# 4               1                0           1           1     Sales staff
# ...           ...              ...         ...         ...             ...
# 36452           1                0           0           0        Managers
# 36453           1                0           1           1  Medicine staff
# 36454           1                0           1           1  Medicine staff
# 36455           1                0           0           0     Sales staff
# 36456           1                0           0           0        Laborers
#
#        CNT_FAM_MEMBERS  STATUS
# 0                  2.0       2
# 1                  2.0       2
# 2                  2.0       1
# 3                  1.0       1
# 4                  1.0       0
# ...                ...     ...
# 36452              2.0       6
# 36453              2.0       6
# 36454              2.0       6
# 36455              2.0       3
# 36456              1.0       3
#
# [36457 rows x 19 columns]

# %%
record.loc[record['DAYS_EMPLOYED']>0,'DAYS_EMPLOYED']=0

# %% [markdown]
# # 2) Visualization

# %% [markdown]
# ## 2.1) Stacked Bar

# %% [markdown]
# ### 2.1.1) Housing Type

# %%
pivot_bar_housing=record.pivot_table(values='ID',index='NAME_HOUSING_TYPE',columns='STATUS',aggfunc=np.size)

# %%
pivot_bar_housing.columns=['Dues Paid','Due 1 Month','Due 2 Months','Due 3 Months','Due 4 Months','Due 5 Months','Due 6 Months']
pivot_bar_housing
# Out:
#                      Dues Paid  Due 1 Month  Due 2 Months  Due 3 Months  \
# NAME_HOUSING_TYPE
# Co-op apartment           30.0        124.0          11.0           NaN
# House / apartment       3967.0      24799.0        3242.0         280.0
# Municipal apartment      145.0        833.0         120.0           8.0
# Office apartment          34.0        190.0          29.0           5.0
# Rented apartment          65.0        430.0          72.0           3.0
# With parents             214.0       1335.0         201.0          18.0
#
#                      Due 4 Months  Due 5 Months  Due 6 Months
# NAME_HOUSING_TYPE
# Co-op apartment               1.0           NaN           2.0
# House / apartment            66.0          39.0         155.0
# Municipal apartment           5.0           5.0          12.0
# Office apartment              2.0           NaN           2.0
# Rented apartment              1.0           NaN           4.0
# With parents                  1.0           2.0           5.0

# %%
fig=plt.figure(1)
df = pd.DataFrame(pivot_bar_housing)
df.plot.bar(stacked=True)
plt.xlabel('Type of Accomodation')
plt.ylabel('Count')
plt.title('Accomodation Type count')
# Out:
# Text(0.5, 1.0, 'Accomodation Type count')

# %%
piv_bar_excel_housing = pd.ExcelWriter('pivot_housing_vs_dues.xlsx')
pivot_bar_housing.to_excel(piv_bar_excel_housing)
piv_bar_excel_housing.save()

# %% [markdown]
# ### 2.1.2) Education Type

# %%
pivot_bar_education=record.pivot_table(values='ID',index='NAME_EDUCATION_TYPE',columns='STATUS',aggfunc=np.size)
pivot_bar_education=pivot_bar_education.reindex(index=['Academic degree','Higher education','Incomplete higher','Secondary / secondary special','Lower secondary'])

# %%
pivot_bar_education.columns=['Dues Paid','Due 1 Month','Due 2 Months','Due 3 Months','Due 4 Months','Due 5 Months','Due 6 Months']
pivot_bar_education
# Out:
#                                Dues Paid  Due 1 Month  Due 2 Months  \
# NAME_EDUCATION_TYPE
# Academic degree                      4.0         21.0           7.0
# Higher education                  1265.0       7451.0         977.0
# Incomplete higher                  152.0       1051.0         174.0
# Secondary / secondary special     2996.0      18891.0        2488.0
# Lower secondary                     38.0        297.0          29.0
#
#                                Due 3 Months  Due 4 Months  Due 5 Months  \
# NAME_EDUCATION_TYPE
# Academic degree                         NaN           NaN           NaN
# Higher education                       80.0          24.0          10.0
# Incomplete higher                      13.0           4.0           9.0
# Secondary / secondary special         218.0          48.0          26.0
# Lower secondary                         3.0           NaN           1.0
#
#                                Due 6 Months
# NAME_EDUCATION_TYPE
# Academic degree                         NaN
# Higher education                       57.0
# Incomplete higher                       7.0
# Secondary / secondary special         110.0
# Lower secondary                         6.0

# %%
fig=plt.figure(2)
df = pd.DataFrame(pivot_bar_education)
df.plot.bar(stacked=True)
plt.xlabel('Education Level')
plt.xlabel('Count')
plt.title('Education Level Count')
# Out:
# Text(0.5, 1.0, 'Education Level Count')

# %%
piv_bar_excel_education = pd.ExcelWriter('pivot_education_vs_dues.xlsx')
pivot_bar_education.to_excel(piv_bar_excel_education)
piv_bar_excel_education.save()

# %% [markdown]
# ### 2.1.3) Income Type

# %%
pivot_bar_incometype=record.pivot_table(values='ID',index='NAME_INCOME_TYPE',columns='STATUS',aggfunc=np.size)

# %%
pivot_bar_incometype.columns=['Dues Paid','Due 1 Month','Due 2 Months','Due 3 Months','Due 4 Months','Due 5 Months','Due 6 Months']
pivot_bar_incometype
# Out:
#                       Dues Paid  Due 1 Month  Due 2 Months  Due 3 Months  \
# NAME_INCOME_TYPE
# Commercial associate     1096.0       6314.0         937.0          60.0
# Pensioner                 752.0       4756.0         514.0          59.0
# State servant             349.0       2251.0         348.0          18.0
# Student                     NaN         10.0           1.0           NaN
# Working                  2258.0      14380.0        1875.0         177.0
#
#                       Due 4 Months  Due 5 Months  Due 6 Months
# NAME_INCOME_TYPE
# Commercial associate          14.0          20.0          49.0
# Pensioner                     26.0           7.0          38.0
# State servant                  8.0           NaN          11.0
# Student                        NaN           NaN           NaN
# Working                       28.0          19.0          82.0

# %%
fig=plt.figure(3)
df = pd.DataFrame(pivot_bar_incometype)
df.plot.bar(stacked=True)
plt.xlabel('Type of Income')
plt.xlabel('Count')
plt.title('Income Type Count')
# Out:
# Text(0.5, 1.0, 'Income Type Count')

# %%
piv_bar_excel_incometype = pd.ExcelWriter('pivot_incometype_vs_dues.xlsx')
pivot_bar_incometype.to_excel(piv_bar_excel_incometype)
piv_bar_excel_incometype.save()

# %% [markdown]
# ### 2.1.4) Family Status

# %%
pivot_bar_familystatus=record.pivot_table(values='ID',index='NAME_FAMILY_STATUS',columns='STATUS',aggfunc=np.size)

# %%
pivot_bar_familystatus.columns=['Dues Paid','Due 1 Month','Due 2 Months','Due 3 Months','Due 4 Months','Due 5 Months','Due 6 Months']
pivot_bar_familystatus
# Out:
#                       Dues Paid  Due 1 Month  Due 2 Months  Due 3 Months  \
# NAME_FAMILY_STATUS
# Civil marriage            380.0       2198.0         321.0          38.0
# Married                  3061.0      19073.0        2521.0         195.0
# Separated                 271.0       1607.0         194.0           4.0
# Single / not married      561.0       3645.0         522.0          50.0
# Widow                     182.0       1188.0         117.0          27.0
#
#                       Due 4 Months  Due 5 Months  Due 6 Months
# NAME_FAMILY_STATUS
# Civil marriage                 2.0           NaN           6.0
# Married                       48.0          25.0         125.0
# Separated                     10.0           4.0          13.0
# Single / not married           6.0          16.0          29.0
# Widow                         10.0           1.0           7.0

# %%
fig=plt.figure(4)
df = pd.DataFrame(pivot_bar_familystatus)
df.plot.bar(stacked=True)
plt.xlabel('Family Status')
plt.xlabel('Count')
plt.title('Family Status count')
# Out:
# Text(0.5, 1.0, 'Family Status count')

# %%
piv_bar_excel_familystatus = pd.ExcelWriter('pivot_familystatus_vs_dues.xlsx')
pivot_bar_familystatus.to_excel(piv_bar_excel_familystatus)
piv_bar_excel_familystatus.save()

# %% [markdown]
# ### 2.1.5) Gender

# %%
pivot_bar_gender=record.pivot_table(values='ID',index='CODE_GENDER',columns='STATUS',aggfunc=np.size)

# %%
record['CODE_GENDER'].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
pivot_bar_gender.columns=['Dues Paid','Due 1 Month','Due 2 Months','Due 3 Months','Due 4 Months','Due 5 Months','Due 6 Months']
pivot_bar_gender.index=['Female','Male']
pivot_bar_gender
# Out:
#         Dues Paid  Due 1 Month  Due 2 Months  Due 3 Months  Due 4 Months  \
# Female       2960        18712          2379           193            54
# Male         1495         8999          1296           121            22
#
#         Due 5 Months  Due 6 Months
# Female            21           111
# Male              25            69

# %%
df = pd.DataFrame(pivot_bar_gender)
df.plot.bar(stacked=True)
plt.xlabel('Gender')
plt.xlabel('Count')
plt.title('Gender count')
# Out:
# Text(0.5, 1.0, 'Gender count')

# %%
piv_bar_excel_gender = pd.ExcelWriter('pivot_gender_vs_dues.xlsx')
pivot_bar_gender.to_excel(piv_bar_excel_gender)
piv_bar_excel_gender.save()

# %% [markdown]
# ### 2.1.6) Occupation Type

# %%
pivot_bar_occupation=record.pivot_table(values='ID',index='OCCUPATION_TYPE',columns='STATUS',aggfunc=np.size)

# %%
pivot_bar_occupation.columns=['Dues Paid','Due 1 Month','Due 2 Months','Due 3 Months','Due 4 Months','Due 5 Months','Due 6 Months']
pivot_bar_occupation
# Out:
#                        Dues Paid  Due 1 Month  Due 2 Months  Due 3 Months  \
# OCCUPATION_TYPE
# Accountants                175.0        919.0         124.0          16.0
# Cleaning staff              56.0        432.0          58.0           2.0
# Cooking staff               80.0        489.0          77.0           4.0
# Core staff                 464.0       2664.0         389.0          25.0
# Drivers                    259.0       1615.0         215.0          34.0
# HR staff                    11.0         60.0          13.0           1.0
# High skill tech staff      152.0       1050.0         151.0          17.0
# IT staff                     8.0         41.0           8.0           1.0
# Laborers                   812.0       4669.0         631.0          51.0
# Low-skill Laborers          30.0        112.0          25.0           6.0
# Managers                   385.0       2237.0         343.0          27.0
# Medicine staff             118.0        926.0         153.0           4.0
# Private service staff       52.0        270.0          20.0           2.0
# Realty agents               12.0         57.0          10.0           NaN
# Sales staff                398.0       2698.0         344.0          25.0
# Secretaries                 11.0        127.0          11.0           NaN
# Security staff              55.0        446.0          78.0           4.0
# Waiters/barmen staff        15.0        140.0          17.0           NaN
#
#                        Due 4 Months  Due 5 Months  Due 6 Months
# OCCUPATION_TYPE
# Accountants                     2.0           2.0           3.0
# Cleaning staff                  1.0           NaN           2.0
# Cooking staff                   NaN           NaN           5.0
# Core staff                     15.0           8.0          26.0
# Drivers                         3.0           5.0           7.0
# HR staff                        NaN           NaN           NaN
# High skill tech staff           1.0           2.0          10.0
# IT staff                        NaN           NaN           2.0
# Laborers                        8.0          12.0          28.0
# Low-skill Laborers              NaN           NaN           2.0
# Managers                        2.0           3.0          15.0
# Medicine staff                  1.0           NaN           5.0
# Private service staff           NaN           NaN           NaN
# Realty agents                   NaN           NaN           NaN
# Sales staff                     7.0           4.0           9.0
# Secretaries                     NaN           NaN           2.0
# Security staff                  1.0           1.0           7.0
# Waiters/barmen staff            1.0           NaN           1.0

# %%
df = pd.DataFrame(pivot_bar_occupation)
df.plot.bar(stacked=True)
plt.xlabel('Occupation Type')
plt.xlabel('Count')
plt.title('Occupation Type count')
# Out:
# Text(0.5, 1.0, 'Occupation Type count')

# %%
piv_bar_excel_occupation = pd.ExcelWriter('pivot_occupation_vs_dues.xlsx')
pivot_bar_occupation.to_excel(piv_bar_excel_occupation)
piv_bar_excel_occupation.save()

# %% [markdown]
# ## 2.2) Pie Chart

# %% [markdown]
# ## 2.2.1) Gender

# %%
pie_chart_gender=record['CODE_GENDER'].value_counts()
pie_chart_gender
# Out:
# F    24430
# M    12027
# Name: CODE_GENDER, dtype: int64

# %%
pie_chart_excel_gender = pd.ExcelWriter('pie_chart_gender.xlsx')
pie_chart_gender.to_excel(pie_chart_excel_gender)
pie_chart_excel_gender.save()

# %% [markdown]
# ### 2.2.2) Status

# %%
pie_chart_status=record['STATUS'].value_counts()
pie_chart_status
# Out:
# 1    27711
# 0     4455
# 2     3675
# 3      314
# 6      180
# 4       76
# 5       46
# Name: STATUS, dtype: int64

# %%
pie_chart_excel_status = pd.ExcelWriter('pie_chart_status.xlsx')
pie_chart_status.to_excel(pie_chart_excel_status)
pie_chart_excel_status.save()

# %% [markdown]
# ## 2.3) Bar Chart

# %% [markdown]
# ### 2.3.1) Count of Income per type

# %%
bar_chart_incometype=record['NAME_INCOME_TYPE'].value_counts()
bar_chart_incometype
# Out:
# Working                 18819
# Commercial associate     8490
# Pensioner                6152
# State servant            2985
# Student                    11
# Name: NAME_INCOME_TYPE, dtype: int64

# %%
bar_chart_excel_incometype = pd.ExcelWriter('bar_chart_incometype.xlsx')
bar_chart_incometype.to_excel(bar_chart_excel_incometype)
bar_chart_excel_incometype.save()

# %% [markdown]
# ## 2.4) Histogram

# %% [markdown]
# ### 2.4.1) Amount of Income

# %%
plt.subplots(figsize=(18,10))
sns.histplot(np.abs(record['AMT_INCOME_TOTAL']),bins=60,kde=True)
plt.xlabel('Income')
plt.title('Age Distribution')
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %% [markdown]
# ### 2.4.2) Age

# %%
plt.subplots(figsize=(18,10))
sns.histplot(np.abs(record['DAYS_BIRTH']/365.25),bins=50,kde=True)
plt.title('Age Distribution')
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %% [markdown]
# ## 2.5) Jointplot

# %%
record
# Out:
#             ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0      5008804           M            Y               Y             0
# 1      5008805           M            Y               Y             0
# 2      5008806           M            Y               Y             0
# 3      5008808           F            N               Y             0
# 4      5008809           F            N               Y             0
# ...        ...         ...          ...             ...           ...
# 36452  5149828           M            Y               Y             0
# 36453  5149834           F            N               Y             0
# 36454  5149838           F            N               Y             0
# 36455  5150049           F            N               Y             0
# 36456  5150337           M            N               Y             0
#
#        AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0              427500.0               Working               Higher education
# 1              427500.0               Working               Higher education
# 2              112500.0               Working  Secondary / secondary special
# 3              270000.0  Commercial associate  Secondary / secondary special
# 4              270000.0  Commercial associate  Secondary / secondary special
# ...                 ...                   ...                            ...
# 36452          315000.0               Working  Secondary / secondary special
# 36453          157500.0  Commercial associate               Higher education
# 36454          157500.0             Pensioner               Higher education
# 36455          283500.0               Working  Secondary / secondary special
# 36456          112500.0               Working  Secondary / secondary special
#
#          NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0            Civil marriage   Rented apartment      -12005          -4542
# 1            Civil marriage   Rented apartment      -12005          -4542
# 2                   Married  House / apartment      -21474          -1134
# 3      Single / not married  House / apartment      -19110          -3051
# 4      Single / not married  House / apartment      -19110          -3051
# ...                     ...                ...         ...            ...
# 36452               Married  House / apartment      -17348          -2420
# 36453               Married  House / apartment      -12387          -1325
# 36454               Married  House / apartment      -12387          -1325
# 36455               Married  House / apartment      -17958           -655
# 36456  Single / not married   Rented apartment       -9188          -1193
#
#        FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 0               1                1           0           0             NaN
# 1               1                1           0           0             NaN
# 2               1                0           0           0  Security staff
# 3               1                0           1           1     Sales staff
# 4               1                0           1           1     Sales staff
# ...           ...              ...         ...         ...             ...
# 36452           1                0           0           0        Managers
# 36453           1                0           1           1  Medicine staff
# 36454           1                0           1           1  Medicine staff
# 36455           1                0           0           0     Sales staff
# 36456           1                0           0           0        Laborers
#
#        CNT_FAM_MEMBERS  STATUS
# 0                  2.0       2
# 1                  2.0       2
# 2                  2.0       1
# 3                  1.0       1
# 4                  1.0       0
# ...                ...     ...
# 36452              2.0       6
# 36453              2.0       6
# 36454              2.0       6
# 36455              2.0       3
# 36456              1.0       3
#
# [36457 rows x 19 columns]

# %% [markdown]
# ### 2.5.1)  Income vs Age

# %%
record['Age']=np.abs(record['DAYS_BIRTH']/365.25)
sns.jointplot(data=record,x='Age',y='AMT_INCOME_TOTAL', kind="scatter", height=10,marginal_kws=dict(bins=50, fill=True))
plt.yticks(np.arange(25000, 1600000, 50000))
plt.xticks(np.arange(20, 75, 5))
plt.xlabel('Age')
plt.ylabel('Income')
plt.show()

# %%
record=record.drop(['Age'],axis=1)

# %% [markdown]
# ## 2.6) Scatter Plot

# %%
record
# Out:
#             ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0      5008804           M            Y               Y             0
# 1      5008805           M            Y               Y             0
# 2      5008806           M            Y               Y             0
# 3      5008808           F            N               Y             0
# 4      5008809           F            N               Y             0
# ...        ...         ...          ...             ...           ...
# 36452  5149828           M            Y               Y             0
# 36453  5149834           F            N               Y             0
# 36454  5149838           F            N               Y             0
# 36455  5150049           F            N               Y             0
# 36456  5150337           M            N               Y             0
#
#        AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0              427500.0               Working               Higher education
# 1              427500.0               Working               Higher education
# 2              112500.0               Working  Secondary / secondary special
# 3              270000.0  Commercial associate  Secondary / secondary special
# 4              270000.0  Commercial associate  Secondary / secondary special
# ...                 ...                   ...                            ...
# 36452          315000.0               Working  Secondary / secondary special
# 36453          157500.0  Commercial associate               Higher education
# 36454          157500.0             Pensioner               Higher education
# 36455          283500.0               Working  Secondary / secondary special
# 36456          112500.0               Working  Secondary / secondary special
#
#          NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0            Civil marriage   Rented apartment      -12005          -4542
# 1            Civil marriage   Rented apartment      -12005          -4542
# 2                   Married  House / apartment      -21474          -1134
# 3      Single / not married  House / apartment      -19110          -3051
# 4      Single / not married  House / apartment      -19110          -3051
# ...                     ...                ...         ...            ...
# 36452               Married  House / apartment      -17348          -2420
# 36453               Married  House / apartment      -12387          -1325
# 36454               Married  House / apartment      -12387          -1325
# 36455               Married  House / apartment      -17958           -655
# 36456  Single / not married   Rented apartment       -9188          -1193
#
#        FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 0               1                1           0           0             NaN
# 1               1                1           0           0             NaN
# 2               1                0           0           0  Security staff
# 3               1                0           1           1     Sales staff
# 4               1                0           1           1     Sales staff
# ...           ...              ...         ...         ...             ...
# 36452           1                0           0           0        Managers
# 36453           1                0           1           1  Medicine staff
# 36454           1                0           1           1  Medicine staff
# 36455           1                0           0           0     Sales staff
# 36456           1                0           0           0        Laborers
#
#        CNT_FAM_MEMBERS  STATUS
# 0                  2.0       2
# 1                  2.0       2
# 2                  2.0       1
# 3                  1.0       1
# 4                  1.0       0
# ...                ...     ...
# 36452              2.0       6
# 36453              2.0       6
# 36454              2.0       6
# 36455              2.0       3
# 36456              1.0       3
#
# [36457 rows x 19 columns]

# %% [markdown]
# ### 2.6.1) Age vs Working age

# %%
record['Years_employed']=np.abs(record.loc[record['DAYS_EMPLOYED']<0,'DAYS_EMPLOYED']/365.25)
record['Age']=np.abs(record.loc[record['DAYS_EMPLOYED']<0,'DAYS_BIRTH']/365.25)
sns.scatterplot(data=record,x='Years_employed',y='Age')
plt.yticks(np.arange(20, 70, 5))
plt.xticks(np.arange(0, 45, 5))
plt.xlabel('Working Age')
plt.show()

# %%
record=record.drop(['Age','Years_employed'],axis=1)

# %% [markdown]
# ## 2.7) Strip plot

# %% [markdown]
# ### 2.7.1) Type of Job vs Salary

# %%
sns.stripplot(data=record,y='OCCUPATION_TYPE',x='AMT_INCOME_TOTAL',hue='OCCUPATION_TYPE',palette="deep",legend=False,s=2)
# Out:
# <AxesSubplot:xlabel='AMT_INCOME_TOTAL', ylabel='OCCUPATION_TYPE'>

# %% [markdown]
# ## 2.8) Box Plot

# %% [markdown]
# ### 2.8.1) Salary Men and Women

# %%
fig, ax = plt.subplots(figsize=(12, 12))
sns.boxplot(data=record,x='AMT_INCOME_TOTAL',y='OCCUPATION_TYPE',hue='CODE_GENDER',ax=ax)
# Out:
# <AxesSubplot:xlabel='AMT_INCOME_TOTAL', ylabel='OCCUPATION_TYPE'>

# %%
sns.boxplot(data=record,y='AMT_INCOME_TOTAL',x='CODE_GENDER',)
# Out:
# <AxesSubplot:xlabel='CODE_GENDER', ylabel='AMT_INCOME_TOTAL'>

# %% [markdown]
# # 3) Pre-Processing for ML

# %%
record['CODE_GENDER'].unique()

# %%
record['FLAG_OWN_CAR'].unique()

# %%
record['FLAG_OWN_REALTY'].unique()

# %%
from function_file import change_to_bi

# %%
change_to_bi(record,'CODE_GENDER')
change_to_bi(record,'FLAG_OWN_CAR')
change_to_bi(record,'FLAG_OWN_REALTY')
record.head()

# %%
record['NAME_EDUCATION_TYPE'].unique() # special type of categorical value

# %%
record['NAME_EDUCATION_TYPE']=record['NAME_EDUCATION_TYPE'].replace(['Lower secondary','Secondary / secondary special','Incomplete higher','Higher education','Academic degree'],[0,1,2,3,4])
record.head()

# %%
record['NAME_INCOME_TYPE'].unique()

# %%
record['NAME_FAMILY_STATUS'].unique()

# %%
record['NAME_HOUSING_TYPE'].unique()

# %%
record['OCCUPATION_TYPE'].unique()

# %%
from function_file import change_to_num # execute this code, if not installed : !pip install ipynb

# %%
change_to_num(record,'NAME_INCOME_TYPE')
change_to_num(record,'NAME_FAMILY_STATUS')
change_to_num(record,'NAME_HOUSING_TYPE')
change_to_num(record,'OCCUPATION_TYPE')
record.head()

# %%
record.loc[record['STATUS']<=1,'STATUS']=0
record.loc[record['STATUS']>1,'STATUS']=1  # on or off
record.head()

# %%
record[record['STATUS']==0]

# %%
record[record['STATUS']==1]

# %% [markdown]
# # 4) Correlation

# %%
record_corr=record

# %%
record

# %%
record_corr['DAYS_EMPLOYED']=record_corr['DAYS_EMPLOYED'] * -1
record_corr['DAYS_BIRTH']=record_corr['DAYS_BIRTH'] * -1

# %%
record

# %%
record_corr.corr()

# %%
record_corr=record_corr.drop(['ID','CODE_GENDER','FLAG_OWN_CAR','FLAG_OWN_REALTY','NAME_INCOME_TYPE','NAME_FAMILY_STATUS','NAME_HOUSING_TYPE','FLAG_MOBIL','FLAG_WORK_PHONE','FLAG_PHONE','FLAG_EMAIL','OCCUPATION_TYPE'],axis=1)

# %%
record_corr.corr()

# %%
sns.set(font_scale=4)
plt.figure(1)
plt.figure(figsize=(32,25))
sns.heatmap(record_corr.corr(),annot=True,cmap='RdYlBu')
sns.set(font_scale=2)
plt.show()

# %% [markdown]
# # 5) Pre Processing based on coorelation graph

# %%
record=record.drop(['ID'],axis=1)
record

# %%
X=record.drop(['FLAG_MOBIL'],axis=1)
X=X.drop(['STATUS'],axis=1) # reference coorelation graph where coorelation is zero
Y=record['STATUS']

# %%
X.head()

# %%
Y.head()

# %% [markdown]
# # 6) Resampling

# %%
from imblearn.combine import SMOTETomek

# %%
X.shape

# %%
Y.shape

# %%
X

# %%
smk=SMOTETomek(random_state=12)
X,Y=smk.fit_resample(X,Y)

# %%
X.shape

# %%
Y.shape

# %% [markdown]
# # 7) PCA

# %%
from sklearn import decomposition
from sklearn import datasets

# %%
pca = decomposition.PCA(n_components=16)
pca.fit_transform(X)
print(pca.explained_variance_ratio_)
pca.fit(X)
X = pca.transform(X)

# %%
Z=np.array([X[:,0],Y])
Z=np.transpose(Z)
Z[Z[:,1]==1,0]

# %%
Z[Z[:,1]==0,0]

# %%
Z.shape

# %%
sns.scatterplot(x=0,y=X[:,0],hue=Y,s=1)

# %%
sns.set(font_scale=1)
pca_df=pd.DataFrame(pca.explained_variance_ratio_)
pca_df.plot.bar()

# %%
X.shape

# %% [markdown]
# # 8) Train-Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test=train_test_split(X,Y,test_size=0.25,random_state=59562)

# %% [markdown]
# # 9) ML Prediction

# %% [markdown]
# ## 9.1) KNN Classification

# %%
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ### 9.1.1) Model

# %%
knn=KNeighborsClassifier(n_neighbors=3)

# %%
knn.fit(X_train,Y_train)

# %%
knn.score(X_test,Y_test)

# %%
Y_pre=knn.predict(X_test)

# %% [markdown]
# ### 9.1.2) Result

# %%
from sklearn.metrics import ConfusionMatrixDisplay

# %%
ConfusionMatrixDisplay.from_predictions(Y_test,Y_pre,cmap='Set3')

# %% [markdown]
# ## 9.2) Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ### 9.2.1) Model

# %%
dtc=DecisionTreeClassifier(criterion="gini")
dtc=dtc.fit(X_train,Y_train)

# %%
dtc.score(X_test,Y_test)

# %%
Y_pre=dtc.predict(X_test)

# %% [markdown]
# ### 9.2.2) Result

# %%
ConfusionMatrixDisplay.from_predictions(Y_test,Y_pre,cmap='Set3')

# %% [markdown]
# ## 9.3) Naive Bais

# %%
from sklearn.naive_bayes import GaussianNB

# %% [markdown]
# ### 9.3.1) Model

# %%
gnb=GaussianNB()
gnb=gnb.fit(X_train,Y_train)

# %%
gnb.score(X_test,Y_test)

# %%
Y_pre=gnb.predict(X_test)

# %% [markdown]
# ### 9.3.2) Result

# %%
ConfusionMatrixDisplay.from_predictions(Y_test,Y_pre,cmap='Set3')
